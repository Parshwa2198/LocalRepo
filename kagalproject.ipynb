# %%
import pandas as pd

df = pd.read_csv("globalAirQuality.csv")

print(df.describe())
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df[["city","aqi"]]
#select rows label and for that loc &Ioc
df.loc[0]
df.loc[0:2]#loc sathe 2 index no data print thase
df.iloc[2]
df.iloc[0:3]
#cells -row and colouma axis but how and albel wher eaxes foer rwa and coloum adn efo rht
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969

# %%
# Select a single column (returns a Series)
df["city"]

# Select multiple columns (returns a DataFrame)
df[["city", "aqi"]]

# Select row with label/index = 2 (using label-based indexing)
df.loc[2]

# Select rows from label/index 0 to 2 (2 is INCLUDED in loc)
df.loc[0:2]

# Select row at position 2 (using position-based indexing)
df.iloc[2]

# Select rows from position 0 to 2 (2 is EXCLUDED in iloc)
df.iloc[0:2]
#cell-row,col
df.loc[0:2,"city","aqi"]
df.columns

df.loc[0:2,"city"]
df.at[0,"city"]
df.iat[0,2]
df["city"]
cities=df["city".copy()]
cities[0]="Mumbai"#copyb
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969
